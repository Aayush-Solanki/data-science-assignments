# %%
import matplotlib.pyplot as plt

# Data
data = [2, 3, 5, 7, 8, 10, 12, 13, 14, 15, 16, 18]

# Create a boxplot
plt.boxplot(data)

# Customize the plot
plt.title("Boxplot of the Data")
plt.xlabel("Data Points")
plt.ylabel("Values")
plt.grid(True)

# Show the plot
plt.show()
